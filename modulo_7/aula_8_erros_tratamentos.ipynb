# %%
print ('ola)
# Out:
#   File "<ipython-input-1-2bcc18f8269c>", line 1
#     print ('ola)
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
def numDiv(num1,num2):
    resultado = num1/num2
    print(resultado)

# %%
numDiv(4,2)
# Out:
# 2.0

# %%
numDiv(4,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-ab1f14e17343> in <module>()
# ----> 1 numDiv(4,0)
#
# <ipython-input-2-94bc8f2ade29> in numDiv(num1, num2)
#       1 def numDiv(num1,num2):
# ----> 2     resultado = num1/num2
#       3     print(resultado)
#
# ZeroDivisionError: division by zero

# %%
7+'s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0ed071cbefb1> in <module>()
# ----> 1 7+'s'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    8+'s'
except TypeError:
    print(" Operacao nao permitida")
# Out:
#  Operacao nao permitida

# %%
try:
    f = open('testandoerros.txt','w')
    f.write(' gravando no arquivo')
except IOError:
    print (" Erro: Arquivo nao encontrado ou nao pode ser salvo.")
else:
    print(" conteudo gravado com sucesso")
    f.close()
# Out:
#  conteudo gravado com sucesso

# %%
try:
    f=open('testandoerros','r')
except IOError:
    print("Error: arquivo nao encontrado ou nao pode ser lido.")
else: 
    print(" Conteudo gravado com sucesso")
# Out:
# Error: arquivo nao encontrado ou nao pode ser lido.

# %%
try:
    f = open('testandoerros.txt','w')
    f.write(' gravando no arquivo')
except IOError:
    print (" Erro: Arquivo nao encontrado ou nao pode ser salvo.")
else:
    print(" conteudo gravado com sucesso")
    f.close()
finally:
    print("blocos de codigo finally sempre sao executados")
# Out:
#  conteudo gravado com sucesso
# blocos de codigo finally sempre sao executados

# %%
def askint():
    try:
        val = int(input("Digite um numero: "))
    except:
        print(" voce nao digitou um numero!")
    finally:
        print(" thank you")
    print (val)

# %%
askint()
# Out:
# Digite um numero: 2
#  thank you
# 2

# %%
def askint():
    try:
        val = int(input("Digite um numero: "))
    except:
        print(" voce nao digitou um numero!")
        val = int(input("Tente novamente. Digite um NUMERO: "))
    finally:
        print(" thank you")
    print (val)

# %%
askint()
# Out:
# Digite um numero: w
#  voce nao digitou um numero!
# Tente novamente. Digite um NUMERO: hue
#  thank you
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8b2fce0dd0b6> in askint()
#       2     try:
# ----> 3         val = int(input("Digite um numero: "))
#       4     except:
#
# ValueError: invalid literal for int() with base 10: 'w'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cc291aa76c10> in <module>()
# ----> 1 askint()
#
# <ipython-input-15-8b2fce0dd0b6> in askint()
#       4     except:
#       5         print(" voce nao digitou um numero!")
# ----> 6         val = int(input("Tente novamente. Digite um NUMERO: "))
#       7     finally:
#       8         print(" thank you")
#
# ValueError: invalid literal for int() with base 10: 'hue'

# %%
def askint():
    while True:
        try:
            val = int(input("Digite um numero: "))
        except:
            print(" voce nao digitou um numero!")
            continue
        else:
            print("obrigado por digitar um numero")
            break
        finally:
            print(" thank you")
        print (val)

# %%
askint()
# Out:
# Digite um numero: h
#  voce nao digitou um numero!
#  thank you
# Digite um numero: huehue
#  voce nao digitou um numero!
#  thank you
# Digite um numero: oioi
#  voce nao digitou um numero!
#  thank you
# Digite um numero: 1
# obrigado por digitar um numero
#  thank you

# %%
tuple = (1,2,3,4,5)
try:
    tuple.append(6)
    for each in tuple:
        print(each)
except AttributeError as e:
    print( ' Erro: ', e)
except IOError as e:
    print('Erro de I/O: ', e)
# Out:
#  Erro:  'tuple' object has no attribute 'append'
