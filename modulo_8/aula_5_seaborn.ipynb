# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sea

# %%
dados = sea.load_dataset('tips')

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sea.jointplot("total_bill", "tip", dados, kind='scatter')

# %%
sea.lmplot("total_bill", "tip", dados, col = "smoker")

# %%
df = pd.DataFrame()

# %%
df['a'] = random.sample(range(1,100), 25)
df['b'] = random.sample(range(1,100), 25)

# %%
df.head()
# Out:
#     a   b
# 0  69  13
# 1  61   1
# 2  68  71
# 3   1  73
# 4  54  69

# %%
sea.lmplot('a','b', data = df, fit_reg = True)

# %%
sea.kdeplot(df.b)

# %%
sea.kdeplot(df.b, df.a)

# %%
sea.distplot(df.a)

# %%
plt.hist(df.a, alpha=.3)
sea.rugplot(df.a)

# %%
sea.boxplot([df.b, df.a])

# %%
sea.violinplot([df.a, df.b])

# %%
sea.heatmap([df.b, df.a], annot = True, fmt = "d")

# %%
sea.clustermap(df)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
# %matplotlib inline

# %%
sea.set(context='notebook', style='darkgrid', palette='dark')

# %%
sea.palplot(sea.color_palette())
sea.palplot(sea.color_palette("husl",8))
sea.palplot(sea.color_palette("hls",8))

# %%
sea.palplot(sea.color_palette("coolwarm",7))

# %%
sea.palplot(sea.cubehelix_palette(8))

# %%
gammas = sea.load_dataset("gammas")
sea.tsplot(gammas, "timepoint", "subject", "ROI", "BOLD signal", color="muted")
# Out:
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
sea.set(style='darkgrid')

dados = sea.load_dataset("tips")
g = sea.FacetGrid(dados, row = "sex", col="time", margin_titles = True)
bins = np.linspace(0,60,13)
g.map(plt.hist, "total_bill", color = "steelblue", bins = bins, lw=0)

# %%
sea.set(style = "white", palette = "muted")
f, axes = plt.subplots(2,2, figsize = (7,7), sharex = True)
sea.despine(left=True)

rs = np.random.RandomState(10)

b,g,r,p = sea.color_palette("muted",4)

d = rs.normal(size=100)

sea.distplot(d, kde = False, color = b, ax = axes[0,0])
sea.distplot(d, hist = False, rug = True, color = r, ax = axes[0,1])
sea.distplot(d, hist = False, color = g, kde_kws = {"shade": True}, ax = axes[1,0])
sea.distplot(d, color = p, ax = axes[1,1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
from scipy.stats import kendalltau
sea.set(style='ticks')

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)
sea.jointplot(x, y, kind = "hex", stat_func = kendalltau, color = "#4CB391")

# %%
sea.set(style="darkgrid")
df = sea.load_dataset("titanic")

pal = dict(male="#6495ED", female="#F08080")
g = sea.lmplot("age", "survived", col = "sex", hue = "sex", data = df, palette = pal, 
               y_jitter = .02, logistic = True)
g.set(xlim=(0,80), ylim = (-.05, 1.05))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-1c3004ed4b7f> in <module>()
#       4 pal = dict(male="#6495ED", female="#F08080")
#       5 g = sea.lmplot("age", "survived", col = "sex", hue = "sex", data = df, palette = pal,
# ----> 6                y_jitter = .02, logistic = True)
#       7 g.set(xlim=(0,80), ylim = (-.05, 1.05))
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     588         scatter_kws=scatter_kws, line_kws=line_kws,
#     589         )
# --> 590     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     591
#     592     # Add a legend
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     807
#     808             # Draw the plot
# --> 809             self._facet_plot(func, ax, args, kwargs)
#     810
#     811         # Finalize the annotations and layout
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     825
#     826         # Draw the plot
# --> 827         func(*plot_args, **plot_kwargs)
#     828
#     829         # Sort out the supporting information
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     788     scatter_kws["marker"] = marker
#     789     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 790     plotter.plot(ax, scatter_kws, line_kws)
#     791     return ax
#     792
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     340             self.scatterplot(ax, scatter_kws)
#     341         if self.fit_reg:
# --> 342             self.lineplot(ax, line_kws)
#     343
#     344         # Label the axes
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     385
#     386         # Fit the regression model
# --> 387         grid, yhat, err_bands = self.fit_regression(ax)
#     388
#     389         # Get set default aesthetics
#
# c:\users\lorensov\anaconda3\envs\data_science\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     195             yhat, yhat_boots = self.fit_poly(grid, self.order)
#     196         elif self.logistic:
# --> 197             from statsmodels.genmod.generalized_linear_model import GLM
#     198             from statsmodels.genmod.families import Binomial
#     199             yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
sea.set(style = "darkgrid")
tips = sea.load_dataset("tips")
color = sea.color_palette()[2]
g = sea.jointplot("total_bill", "tip", data=tips, kind = "reg", xlim = (0,60),
                ylim = (0,12), color = color, size = 7)

# %%
sea.set(style = "darkgrid")
df = sea.load_dataset("iris")
sea.pairplot(df, hue = "species", size = 2.5)
